# %%
num= 12345678
# count=0
# for i in range(len(str(num))):
#     count+=1
# print(count)print(le
print(len(str(num)))
# Out:
# 8

# %%
num=12345
sum=0
for i in range(len(str(num))+1):
    sum+=i
print(sum)
# Out:
# 15

# %%
num=eval("Enter your num: ")
power=len(str(num))
total=0
for i in str(num):
    total+=int(i)**power
if total==num:
    print(f"The {num} is Armstrong")
       
else:
    print(f"The {num} is Not Armstrong")
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\KING\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[2], line 1
#     num=eval("Enter your num: ")
#
#   File <string>:1
#     Enter your num:
#           ^
# SyntaxError: invalid syntax
